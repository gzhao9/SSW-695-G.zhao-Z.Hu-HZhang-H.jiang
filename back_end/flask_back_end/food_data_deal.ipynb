# %%
import requests
import json
import pandas as pd

foodName = 'Cheddar cheese'
apiKey = 'JkdjMHjQobEeEAVSkii5eg1n5NtTKH0AAL0FgXBb'

url = f'https://api.nal.usda.gov/fdc/v1/foods/search?api_key={apiKey}&query={foodName}'
res = requests.get(url)
print(res.status_code)
# Out:
# 200

# %%
from unittest import result
from flask import Flask,make_response,json,render_template,request,redirect,url_for
import json
import get_food_nutrient
import csv

# %%
with open('USER_INFO\\USER_BASE_INFO.CSV', mode='r') as inp:
    reader = csv.reader(inp)
    user_info = [rows for rows in reader if rows[1]=="GW" or rows[0]=='info_id']

# %%
user_info
# Out:
# [['info_id',
#   'user_id',
#   'name',
#   'hight',
#   'weight',
#   'fat_rate',
#   'age',
#   'gender',
#   'daily_cal',
#   'date']]

# %%
response = res.json()

# %%
type(response)
# Out:
# dict

# %%
response['foods'][0]
# Out:
# {'fdcId': 1104067,
#  'description': '100 GRAND Bar',
#  'lowercaseDescription': '100 grand bar',
#  'commonNames': '',
#  'additionalDescriptions': '$ 100,000 Bar',
#  'dataType': 'Survey (FNDDS)',
#  'foodCode': 91715300,
#  'publishedDate': '2020-10-30',
#  'foodCategory': 'Candy containing chocolate',
#  'foodCategoryId': 999786,
#  'allHighlightFields': '',
#  'score': 1.0,
#  'foodNutrients': [{'nutrientId': 1003,
#    'nutrientName': 'Protein',
#    'nutrientNumber': '203',
#    'unitName': 'G',
#    'value': 2.5,
#    'rank': 600,
#    'indentLevel': 1,
#    'foodNutrientId': 13301423},
#   {'nutrientId': 1004,
#    'nutrientName': 'Total lipid (fat)',
#    'nutrientNumber': '204',
#    'unitName': 'G',
#    'value': 19.3,
#    'rank': 800,
#    'indentLevel': 1,
#    'foodNutrientId': 13301424},
#   {'nutrientId': 1005,
#    'nutrientName': 'Carbohydrate, by difference',
#    'nutrientNumber': '205',
#    'unitName': 'G',
#    'value': 71.0,
#    'rank': 1110,
#    'indentLevel': 2,
#    'foodNutrientId': 13301425},
#   {'nutrientId': 1008,
#    'nutrientName': 'Energy',
#    'nutrientNumber': '208',
#    'unitName': 'KCAL',
#    'value': 468,
#    'rank': 300,
#    'indentLevel': 1,
#    'foodNutrientId': 13301426},
#   {'nutrientId': 1018,
#    'nutrientName': 'Alcohol, ethyl',
#    'nutrientNumber': '221',
#    'unitName': 'G',
#    'value': 0.0,
#    'rank': 18200,
#    'indentLevel': 1,
#    'foodNutrientId': 13301427},
#   {'nutrientId': 1051,
#    'nutrientName': 'Water',
#    'nutrientNumber': '255',
#    'unitName': 'G',
#    'value': 6.1,
#    'rank': 100,
#    'indentLevel': 1,
#    'foodNutrientId': 13301428},
#   {'nutrientId': 1057,
#    'nutrientName': 'Caffeine',
#    'nutrientNumber': '262',
#    'unitName': 'MG',
#    'value': 8.0,
#    'rank': 18300,
#    'indentLevel': 0,
#    'foodNutrientId': 13301429},
#   {'nutrientId': 1058,
#    'nutrientName': 'Theobromine',
#    'nutrientNumber': '263',
#    'unitName': 'MG',
#    'value': 55.0,
#    'rank': 18400,
#    'indentLevel': 0,
#    'foodNutrientId': 13301430},
#   {'nutrientId': 2000,
#    'nutrientName': 'Sugars, total including NLEA',
#    'nutrientNumber': '269',
#    'unitName': 'G',
#    'value': 51.9,
#    'rank': 1510,
#    'indentLevel': 3,
#    'foodNutrientId': 13301431},
#   {'nutrientId': 1079,
#    'nutrientName': 'Fiber, total dietary',
#    'nutrientNumber': '291',
#    'unitName': 'G',
#    'value': 1.0,
#    'rank': 1200,
#    'indentLevel': 3,
#    'foodNutrientId': 13301432},
#   {'nutrientId': 1087,
#    'nutrientName': 'Calcium, Ca',
#    'nutrientNumber': '301',
#    'unitName': 'MG',
#    'value': 76.0,
#    'rank': 5300,
#    'indentLevel': 1,
#    'foodNutrientId': 13301433},
#   {'nutrientId': 1089,
#    'nutrientName': 'Iron, Fe',
#    'nutrientNumber': '303',
#    'unitName': 'MG',
#    'value': 0.34,
#    'rank': 5400,
#    'indentLevel': 1,
#    'foodNutrientId': 13301434},
#   {'nutrientId': 1090,
#    'nutrientName': 'Magnesium, Mg',
#    'nutrientNumber': '304',
#    'unitName': 'MG',
#    'value': 25.0,
#    'rank': 5500,
#    'indentLevel': 1,
#    'foodNutrientId': 13301435},
#   {'nutrientId': 1091,
#    'nutrientName': 'Phosphorus, P',
#    'nutrientNumber': '305',
#    'unitName': 'MG',
#    'value': 86.0,
#    'rank': 5600,
#    'indentLevel': 1,
#    'foodNutrientId': 13301436},
#   {'nutrientId': 1092,
#    'nutrientName': 'Potassium, K',
#    'nutrientNumber': '306',
#    'unitName': 'MG',
#    'value': 163,
#    'rank': 5700,
#    'indentLevel': 1,
#    'foodNutrientId': 13301437},
#   {'nutrientId': 1093,
#    'nutrientName': 'Sodium, Na',
#    'nutrientNumber': '307',
#    'unitName': 'MG',
#    'value': 203,
#    'rank': 5800,
#    'indentLevel': 1,
#    'foodNutrientId': 13301438},
#   {'nutrientId': 1095,
#    'nutrientName': 'Zinc, Zn',
#    'nutrientNumber': '309',
#    'unitName': 'MG',
#    'value': 0.99,
#    'rank': 5900,
#    'indentLevel': 1,
#    'foodNutrientId': 13301439},
#   {'nutrientId': 1098,
#    'nutrientName': 'Copper, Cu',
#    'nutrientNumber': '312',
#    'unitName': 'MG',
#    'value': 0.185,
#    'rank': 6000,
#    'indentLevel': 1,
#    'foodNutrientId': 13301440},
#   {'nutrientId': 1103,
#    'nutrientName': 'Selenium, Se',
#    'nutrientNumber': '317',
#    'unitName': 'UG',
#    'value': 2.5,
#    'rank': 6200,
#    'indentLevel': 1,
#    'foodNutrientId': 13301441},
#   {'nutrientId': 1105,
#    'nutrientName': 'Retinol',
#    'nutrientNumber': '319',
#    'unitName': 'UG',
#    'value': 37.0,
#    'rank': 7430,
#    'indentLevel': 2,
#    'foodNutrientId': 13301442},
#   {'nutrientId': 1106,
#    'nutrientName': 'Vitamin A, RAE',
#    'nutrientNumber': '320',
#    'unitName': 'UG',
#    'value': 38.0,
#    'rank': 7420,
#    'indentLevel': 1,
#    'foodNutrientId': 13301443},
#   {'nutrientId': 1107,
#    'nutrientName': 'Carotene, beta',
#    'nutrientNumber': '321',
#    'unitName': 'UG',
#    'value': 3.0,
#    'rank': 7440,
#    'indentLevel': 2,
#    'foodNutrientId': 13301444},
#   {'nutrientId': 1108,
#    'nutrientName': 'Carotene, alpha',
#    'nutrientNumber': '322',
#    'unitName': 'UG',
#    'value': 0.0,
#    'rank': 7450,
#    'indentLevel': 2,
#    'foodNutrientId': 13301445},
#   {'nutrientId': 1109,
#    'nutrientName': 'Vitamin E (alpha-tocopherol)',
#    'nutrientNumber': '323',
#    'unitName': 'MG',
#    'value': 0.42,
#    'rank': 7905,
#    'indentLevel': 1,
#    'foodNutrientId': 13301446},
#   {'nutrientId': 1114,
#    'nutrientName': 'Vitamin D (D2 + D3)',
#    'nutrientNumber': '328',
#    'unitName': 'UG',
#    'value': 0.0,
#    'rank': 8700,
#    'indentLevel': 1,
#    'foodNutrientId': 13301447},
#   {'nutrientId': 1120,
#    'nutrientName': 'Cryptoxanthin, beta',
#    'nutrientNumber': '334',
#    'unitName': 'UG',
#    'value': 0.0,
#    'rank': 7460,
#    'indentLevel': 2,
#    'foodNutrientId': 13301448},
#   {'nutrientId': 1122,
#    'nutrientName': 'Lycopene',
#    'nutrientNumber': '337',
#    'unitName': 'UG',
#    'value': 0.0,
#    'rank': 7530,
#    'indentLevel': 1,
#    'foodNutrientId': 13301449},
#   {'nutrientId': 1123,
#    'nutrientName': 'Lutein + zeaxanthin',
#    'nutrientNumber': '338',
#    'unitName': 'UG',
#    'value': 2.0,
#    'rank': 7560,
#    'indentLevel': 1,
#    'foodNutrientId': 13301450},
#   {'nutrientId': 1162,
#    'nutrientName': 'Vitamin C, total ascorbic acid',
#    'nutrientNumber': '401',
#    'unitName': 'MG',
#    'value': 0.7,
#    'rank': 6300,
#    'indentLevel': 1,
#    'foodNutrientId': 13301451},
#   {'nutrientId': 1165,
#    'nutrientName': 'Thiamin',
#    'nutrientNumber': '404',
#    'unitName': 'MG',
#    'value': 0.058,
#    'rank': 6400,
#    'indentLevel': 1,
#    'foodNutrientId': 13301452},
#   {'nutrientId': 1166,
#    'nutrientName': 'Riboflavin',
#    'nutrientNumber': '405',
#    'unitName': 'MG',
#    'value': 0.119,
#    'rank': 6500,
#    'indentLevel': 1,
#    'foodNutrientId': 13301453},
#   {'nutrientId': 1167,
#    'nutrientName': 'Niacin',
#    'nutrientNumber': '406',
#    'unitName': 'MG',
#    'value': 0.198,
#    'rank': 6600,
#    'indentLevel': 1,
#    'foodNutrientId': 13301454},
#   {'nutrientId': 1175,
#    'nutrientName': 'Vitamin B-6',
#    'nutrientNumber': '415',
#    'unitName': 'MG',
#    'value': 0.016,
#    'rank': 6800,
#    'indentLevel': 1,
#    'foodNutrientId': 13301455},
#   {'nutrientId': 1177,
#    'nutrientName': 'Folate, total',
#    'nutrientNumber': '417',
#    'unitName': 'UG',
#    'value': 5.0,
#    'rank': 6900,
#    'indentLevel': 1,
#    'foodNutrientId': 13301456},
#   {'nutrientId': 1178,
#    'nutrientName': 'Vitamin B-12',
#    'nutrientNumber': '418',
#    'unitName': 'UG',
#    'value': 0.29,
#    'rank': 7300,
#    'indentLevel': 1,
#    'foodNutrientId': 13301457},
#   {'nutrientId': 1180,
#    'nutrientName': 'Choline, total',
#    'nutrientNumber': '421',
#    'unitName': 'MG',
#    'value': 24.6,
#    'rank': 7220,
#    'indentLevel': 1,
#    'foodNutrientId': 13301458},
#   {'nutrientId': 1185,
#    'nutrientName': 'Vitamin K (phylloquinone)',
#    'nutrientNumber': '430',
#    'unitName': 'UG',
#    'value': 6.2,
#    'rank': 8800,
#    'indentLevel': 1,
#    'foodNutrientId': 13301459},
#   {'nutrientId': 1186,
#    'nutrientName': 'Folic acid',
#    'nutrientNumber': '431',
#    'unitName': 'UG',
#    'value': 0.0,
#    'rank': 7000,
#    'indentLevel': 0,
#    'foodNutrientId': 13301460},
#   {'nutrientId': 1187,
#    'nutrientName': 'Folate, food',
#    'nutrientNumber': '432',
#    'unitName': 'UG',
#    'value': 5.0,
#    'rank': 7100,
#    'indentLevel': 1,
#    'foodNutrientId': 13301461},
#   {'nutrientId': 1190,
#    'nutrientName': 'Folate, DFE',
#    'nutrientNumber': '435',
#    'unitName': 'UG',
#    'value': 5.0,
#    'rank': 7200,
#    'indentLevel': 1,
#    'foodNutrientId': 13301462},
#   {'nutrientId': 1242,
#    'nutrientName': 'Vitamin E, added',
#    'nutrientNumber': '573',
#    'unitName': 'MG',
#    'value': 0.0,
#    'rank': 7920,
#    'indentLevel': 0,
#    'foodNutrientId': 13301463},
#   {'nutrientId': 1246,
#    'nutrientName': 'Vitamin B-12, added',
#    'nutrientNumber': '578',
#    'unitName': 'UG',
#    'value': 0.0,
#    'rank': 7340,
#    'indentLevel': 0,
#    'foodNutrientId': 13301464},
#   {'nutrientId': 1253,
#    'nutrientName': 'Cholesterol',
#    'nutrientNumber': '601',
#    'unitName': 'MG',
#    'value': 12.0,
#    'rank': 15700,
#    'indentLevel': 1,
#    'foodNutrientId': 13301465},
#   {'nutrientId': 1258,
#    'nutrientName': 'Fatty acids, total saturated',
#    'nutrientNumber': '606',
#    'unitName': 'G',
#    'value': 11.9,
#    'rank': 9700,
#    'indentLevel': 1,
#    'foodNutrientId': 13301466},
#   {'nutrientId': 1259,
#    'nutrientName': 'SFA 4:0',
#    'nutrientNumber': '607',
#    'unitName': 'G',
#    'value': 0.356,
#    'rank': 9800,
#    'indentLevel': 2,
#    'foodNutrientId': 13301467},
#   {'nutrientId': 1260,
#    'nutrientName': 'SFA 6:0',
#    'nutrientNumber': '608',
#    'unitName': 'G',
#    'value': 0.169,
#    'rank': 9900,
#    'indentLevel': 2,
#    'foodNutrientId': 13301468},
#   {'nutrientId': 1261,
#    'nutrientName': 'SFA 8:0',
#    'nutrientNumber': '609',
#    'unitName': 'G',
#    'value': 0.322,
#    'rank': 10000,
#    'indentLevel': 2,
#    'foodNutrientId': 13301469},
#   {'nutrientId': 1262,
#    'nutrientName': 'SFA 10:0',
#    'nutrientNumber': '610',
#    'unitName': 'G',
#    'value': 0.329,
#    'rank': 10100,
#    'indentLevel': 2,
#    'foodNutrientId': 13301470},
#   {'nutrientId': 1263,
#    'nutrientName': 'SFA 12:0',
#    'nutrientNumber': '611',
#    'unitName': 'G',
#    'value': 1.44,
#    'rank': 10300,
#    'indentLevel': 2,
#    'foodNutrientId': 13301471},
#   {'nutrientId': 1264,
#    'nutrientName': 'SFA 14:0',
#    'nutrientNumber': '612',
#    'unitName': 'G',
#    'value': 1.03,
#    'rank': 10500,
#    'indentLevel': 2,
#    'foodNutrientId': 13301472},
#   {'nutrientId': 1265,
#    'nutrientName': 'SFA 16:0',
#    'nutrientNumber': '613',
#    'unitName': 'G',
#    'value': 4.31,
#    'rank': 10700,
#    'indentLevel': 2,
#    'foodNutrientId': 13301473},
#   {'nutrientId': 1266,
#    'nutrientName': 'SFA 18:0',
#    'nutrientNumber': '614',
#    'unitName': 'G',
#    'value': 3.75,
#    'rank': 10900,
#    'indentLevel': 2,
#    'foodNutrientId': 13301474},
#   {'nutrientId': 1268,
#    'nutrientName': 'MUFA 18:1',
#    'nutrientNumber': '617',
#    'unitName': 'G',
#    'value': 5.77,
#    'rank': 12100,
#    'indentLevel': 2,
#    'foodNutrientId': 13301475},
#   {'nutrientId': 1269,
#    'nutrientName': 'PUFA 18:2',
#    'nutrientNumber': '618',
#    'unitName': 'G',
#    'value': 1.26,
#    'rank': 13100,
#    'indentLevel': 2,
#    'foodNutrientId': 13301476},
#   {'nutrientId': 1270,
#    'nutrientName': 'PUFA 18:3',
#    'nutrientNumber': '619',
#    'unitName': 'G',
#    'value': 0.129,
#    'rank': 13900,
#    'indentLevel': 2,
#    'foodNutrientId': 13301477},
#   {'nutrientId': 1271,
#    'nutrientName': 'PUFA 20:4',
#    'nutrientNumber': '620',
#    'unitName': 'G',
#    'value': 0.0,
#    'rank': 14700,
#    'indentLevel': 2,
#    'foodNutrientId': 13301478},
#   {'nutrientId': 1272,
#    'nutrientName': 'PUFA 22:6 n-3 (DHA)',
#    'nutrientNumber': '621',
#    'unitName': 'G',
#    'value': 0.0,
#    'rank': 15300,
#    'indentLevel': 2,
#    'foodNutrientId': 13301479},
#   {'nutrientId': 1275,
#    'nutrientName': 'MUFA 16:1',
#    'nutrientNumber': '626',
#    'unitName': 'G',
#    'value': 0.183,
#    'rank': 11700,
#    'indentLevel': 2,
#    'foodNutrientId': 13301480},
#   {'nutrientId': 1276,
#    'nutrientName': 'PUFA 18:4',
#    'nutrientNumber': '627',
#    'unitName': 'G',
#    'value': 0.0,
#    'rank': 14250,
#    'indentLevel': 2,
#    'foodNutrientId': 13301481},
#   {'nutrientId': 1277,
#    'nutrientName': 'MUFA 20:1',
#    'nutrientNumber': '628',
#    'unitName': 'G',
#    'value': 0.004,
#    'rank': 12400,
#    'indentLevel': 2,
#    'foodNutrientId': 13301482},
#   {'nutrientId': 1278,
#    'nutrientName': 'PUFA 2:5 n-3 (EPA)',
#    'nutrientNumber': '629',
#    'unitName': 'G',
#    'value': 0.0,
#    'rank': 15000,
#    'indentLevel': 2,
#    'foodNutrientId': 13301483},
#   {'nutrientId': 1279,
#    'nutrientName': 'MUFA 22:1',
#    'nutrientNumber': '630',
#    'unitName': 'G',
#    'value': 0.0,
#    'rank': 12500,
#    'indentLevel': 2,
#    'foodNutrientId': 13301484},
#   {'nutrientId': 1280,
#    'nutrientName': 'PUFA 22:5 n-3 (DPA)',
#    'nutrientNumber': '631',
#    'unitName': 'G',
#    'value': 0.0,
#    'rank': 15200,
#    'indentLevel': 2,
#    'foodNutrientId': 13301485},
#   {'nutrientId': 1292,
#    'nutrientName': 'Fatty acids, total monounsaturated',
#    'nutrientNumber': '645',
#    'unitName': 'G',
#    'value': 6.04,
#    'rank': 11400,
#    'indentLevel': 1,
#    'foodNutrientId': 13301486},
#   {'nutrientId': 1293,
#    'nutrientName': 'Fatty acids, total polyunsaturated',
#    'nutrientNumber': '646',
#    'unitName': 'G',
#    'value': 1.39,
#    'rank': 12900,
#    'indentLevel': 1,
#    'foodNutrientId': 13301487}],
#  'finalFoodInputFoods': [{'foodDescription': 'Candies, NESTLE, 100 GRAND Bar',
#    'gramWeight': 100,
#    'id': 102104,
#    'portionCode': '0',
#    'portionDescription': 'NONE',
#    'unit': 'GM',
#    'rank': 1,
#    'srCode': 19144,
#    'value': 100}],
#  'foodMeasures': [{'disseminationText': '1 bar (1.5 oz)',
#    'gramWeight': 43,
#    'id': 246540,
#    'modifier': '60362',
#    'rank': 1,
#    'measureUnitAbbreviation': 'undetermined',
#    'measureUnitName': 'undetermined',
#    'measureUnitId': 9999},
#   {'disseminationText': 'Quantity not specified',
#    'gramWeight': 21,
#    'id': 266827,
#    'modifier': '90000',
#    'rank': 2,
#    'measureUnitAbbreviation': 'undetermined',
#    'measureUnitName': 'undetermined',
#    'measureUnitId': 9999}],
#  'foodAttributes': [],
#  'foodAttributeTypes': [{'name': 'Additional Description',
#    'description': 'Additional descriptions for the food.',
#    'id': 1001,
#    'foodAttributes': [{'value': '$ 100,000 Bar',
#      'id': 978293,
#      'sequenceNumber': 1}]},
#   {'name': 'Attribute',
#    'description': 'Generic attributes',
#    'id': 999,
#    'foodAttributes': [{'value': '5702',
#      'name': 'WWEIA Category number',
#      'id': 991595},
#     {'value': 'Candy containing chocolate',
#      'name': 'WWEIA Category description',
#      'id': 999786}]}],
#  'foodVersionIds': []}

# %%
len(response['foods'])
# Out:
# 50

# %%
foodCategory = response['foods'][0]['foodCategory']

# %%
foodCategory = response['foods'][0]['dataType']
foodCategory
len(response['foods'])
# Out:
# 50

# %%
foodWeight = response['foods'][0]['packageWeight']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\admin\Documents\GitHub\SSW-695-G.zhao-Z.Hu-HZhang-H.jiang\back_end\flask_back_end\food_data_deal.ipynb Cell 12' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/admin/Documents/GitHub/SSW-695-G.zhao-Z.Hu-HZhang-H.jiang/back_end/flask_back_end/food_data_deal.ipynb#ch0000016?line=0'>1</a> foodWeight = response['foods'][0]['packageWeight']
#
# KeyError: 'packageWeight'

# %%
protein = response['foods'][0]['foodNutrients'][0]['value']
fat = response['foods'][0]['foodNutrients'][1]['value']
carbohydrate = response['foods'][0]['foodNutrients'][2]['value']
energy = response['foods'][0]['foodNutrients'][3]['value']
sugre = response['foods'][0]['foodNutrients'][4]['value']
vitamin_A = response['foods'][0]['foodNutrients'][9]['value']
vitamin_C = response['foods'][0]['foodNutrients'][10]['value']

# %%
foodDict = {
    'Food Name': foodName,
    'Food Category': foodCategory,
    'Food Weight': foodWeight,
    'Protein': protein,
    'Fat':fat,
    'Carbohydrate':carbohydrate,
    'Energy':energy,
    'Sugre':sugre,
    'Vitamin_A':vitamin_A,
    'Vitamin_C':vitamin_C
}

# %%
foodDict
# Out:
# {'Food Name': 'Cheddar cheese',
#  'Food Category': 'Branded',
#  'Food Weight': '8 oz/226 g',
#  'Protein': 25.0,
#  'Fat': 32.1,
#  'Carbohydrate': 3.57,
#  'Energy': 393,
#  'Sugre': 0.0,
#  'Vitamin_A': 1070.0,
#  'Vitamin_C': 0.0}
